# %%
import graphlab

# %%
image_train=graphlab.SFrame('/Users/apple/Desktop/image_train_data')
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to kobecool248@163.com and will expire on March 05, 2018.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1489327614.log

# %%
image_test=graphlab.SFrame('/Users/apple/Desktop/image_test_data')

# %%
knnm=graphlab.nearest_neighbors.create(image_train,features=['deep_features'], label='id')
# Out:
# Starting brute force nearest neighbors model training.

# %%
graphlab.canvas.set_target('ipynb')

# %%
cat = image_train[18:19]
cat['image'].show()

# %%
knnm.query(cat)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.0498753   | 32.832ms     |
# | Done         |         | 100         | 275.4ms      |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	int
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+---------------+------+
# | query_label | reference_label |    distance   | rank |
# +-------------+-----------------+---------------+------+
# |      0      |       384       |      0.0      |  1   |
# |      0      |       6910      | 36.9403137951 |  2   |
# |      0      |      39777      | 38.4634888975 |  3   |
# |      0      |      36870      | 39.7559623119 |  4   |
# |      0      |      41734      | 39.7866014148 |  5   |
# ...

# %%
def get_images_from_ids(query_result):
    return image_train.filter_by(query_result['reference_label'],'id')

# %%
cat_neighbors = get_images_from_ids(knnm.query(cat))
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.0498753   | 21.952ms     |
# | Done         |         | 100         | 253.009ms    |
# +--------------+---------+-------------+--------------+

# %%
cat_neighbors['image'].show()

# %%
show_neighbors= lambda i: get_images_from_ids(knnm.query(image_train[i:i+1]))['image'].show()

# %%
show_neighbors(21)
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.0498753   | 33.483ms     |
# | Done         |         | 100         | 268.225ms    |
# +--------------+---------+-------------+--------------+
